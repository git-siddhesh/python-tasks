# %% [markdown]
# <a href="https://colab.research.google.com/github/git-siddhesh/python-tasks/blob/master/tryonInternetSpeed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests as rq
r=rq.get('https://fast.com')
r.content
#y=[i for i in data if i=='id="speed-value"']
# Out:
# b'<!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd">\n<!-- htmllint id-class-style="dash" -->\n<!-- htmllint attr-name-style="dash" -->\n<html>\n    <head profile="http://www.w3.org/2005/10/profile">\n        <meta http-equiv="content-type" content="text/html; charset=UTF-8">\n        <meta charset="UTF-8">\n        <meta name="description" content="How fast is your download speed? In seconds, FAST.com&#39;s simple Internet speed test will estimate your ISP speed.">\n        <link href="https://fast.com" rel="canonical">\n\n        <link rel="alternate" hreflang="id" href="https://fast.com/id/" />\n        <link rel="alternate" hreflang="da" href="https://fast.com/da/" />\n        <link rel="alternate" hreflang="de" href="https://fast.com/de/" />\n        <link rel="alternate" hreflang="en-GB" href="https://fast.com/en/gb/" />\n        <link rel="alternate" hreflang="en" href="https://fast.com" />\n        <link rel="alternate" hreflang="es-ES" href="https://fast.com/es/es/" />\n        <link rel="alternate" hreflang="es" href="https://fast.com/es/" />\n        <link rel="alternate" hreflang="fr-CA" href="https://fast.com/fr/ca/" />\n        <link rel="alternate" hreflang="fr" href="https://fast.com/fr/" />\n        <link rel="alternate" hreflang="it" href="https://fast.com/it/" />\n        <link rel="alternate" hreflang="nl" href="https://fast.com/nl/" />\n        <link rel="alternate" hreflang="nb" href="https://fast.com/nb/" />\n        <link rel="alternate" hreflang="pl" href="https://fast.com/pl/" />\n        <link rel="alternate" hreflang="pt" href="https://fast.com/pt/" />\n        <link rel="alternate" hreflang="pt-PT" href="https://fast.com/pt/pt/" />\n        <link rel="alternate" hreflang="ro" href="https://fast.com/ro/" />\n        <link rel="alternate" hreflang="fi" href="https://fast.com/fi/" />\n        <link rel="alternate" hreflang="sv" href="https://fast.com/sv/" />\n        <link rel="alternate" hreflang="tr" href="https://fast.com/tr/" />\n        <link rel="alternate" hreflang="el" href="https://fast.com/el/" />\n        <link rel="alternate" hreflang="he" href="https://fast.com/he/" />\n        <link rel="alternate" hreflang="ar" href="https://fast.com/ar/" />\n        <link rel="alternate" hreflang="th" href="https://fast.com/th/" />\n        <link rel="alternate" hreflang="zh-CN" href="https://fast.com/zh/cn/" />\n        <link rel="alternate" hreflang="zh-TW" href="https://fast.com/zh/tw/" />\n        <link rel="alternate" hreflang="ja" href="https://fast.com/ja/" />\n        <link rel="alternate" hreflang="ko" href="https://fast.com/ko/" />\n        <link type="text/css" rel="stylesheet" href="/app-809f4b.css" media="all">\n        <link type="text/css" rel="stylesheet" href="/assets/fonts/oc-webfont.min.css" media="all">\n        <link rel="icon" type="image/png" href="/assets/favicons/favicon-96x96.png" />\n        <link rel="apple-touch-icon" sizes="57x57" href="/assets/favicons/apple-icon-57x57.png">\n        <link rel="apple-touch-icon" sizes="60x60" href="/assets/favicons/apple-icon-60x60.png">\n        <link rel="apple-touch-icon" sizes="72x72" href="/assets/favicons/apple-icon-72x72.png">\n        <link rel="apple-touch-icon" sizes="76x76" href="/assets/favicons/apple-icon-76x76.png">\n        <link rel="apple-touch-icon" sizes="114x114" href="/assets/favicons/apple-icon-114x114.png">\n        <link rel="apple-touch-icon" sizes="120x120" href="/assets/favicons/apple-icon-120x120.png">\n        <link rel="apple-touch-icon" sizes="144x144" href="/assets/favicons/apple-icon-144x144.png">\n        <link rel="apple-touch-icon" sizes="152x152" href="/assets/favicons/apple-icon-152x152.png">\n        <link rel="apple-touch-icon" sizes="180x180" href="/assets/favicons/apple-icon-180x180.png">\n        <link rel="icon" type="image/png" sizes="192x192"  href="/assets/favicons/android-icon-192x192.png">\n        <link rel="icon" type="image/png" sizes="32x32" href= ...

# %%
import requests
import time
import os

def get_seconds(datetime):
    time = datetime.split(' ')[3].split(':')
    time_hours = int(time[0])
    time_minutes = int(time[1])
    time_seconds = int(time[2])
    return time_hours*360 + time_minutes*60 + time_seconds
def downspeed():
    '''url = "http://speedtest.ftp.otenet.gr/files/test100k.db"
    current_seconds = get_seconds(time.asctime())
    file = requests.get(url)
    headers = file.headers
    file_size = int(headers['Content-Length'])/1000
    dl_seconds = get_seconds(time.asctime())
    time_difference = dl_seconds - current_seconds
    return round(file_size / time_difference)'''
    url = "http://speedtest.ftp.otenet.gr/files/test100k.db"
    start = time.time()
    file = requests.get(url)
    end = time.time()
    time_difference = end - start
    file_size = int(file.headers['Content-Length'])/1000    
    return round(file_size / time_difference)
def upspeed():
    #current_seconds = get_seconds(time.asctime())
    current_seconds=time.time()
    dummy_file = os.path.join(os.getenv('APPDATA'), 'dummy.txt')
    post_url = 'http://httpbin.org/post'
    with open(dummy_file, 'wb') as dummy:
        for i in range (1500):
            dummy.write(str.encode('This is a dummy text. Its sole propose is being uploaded to a server. '))
        dummy.close()
    files = {'file' : open(dummy_file, 'rb')}
    request = requests.post(post_url, data=files)
    headers = request.headers
    dl_seconds=time.time()
    file_size = int(headers['Content-Length'])/1000
    #dl_seconds = get_seconds(time.asctime())
    time_difference = dl_seconds - current_seconds
    return round(file_size / time_difference)
if __name__ == '__main__':
    while True:
        up = None
        down = None
        if up == None and down == None:
            up=upspeed()
            down=downspeed()
            print('At {0} your Downspeed is: {1}, and your Upspeed is: {2}'.format(time.asctime(), down, up))
            time.sleep(5)
            up=None
            down=None
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-20f7326af753> in <module>()
#      47         down = None
#      48         if up == None and down == None:
# ---> 49             up=upspeed()
#      50             down=downspeed()
#      51             print('At {0} your Downspeed is: {1}, and your Upspeed is: {2}'.format(time.asctime(), down, up))
#
# <ipython-input-16-20f7326af753> in upspeed()
#      28     #current_seconds = get_seconds(time.asctime())
#      29     current_seconds=time.time()
# ---> 30     dummy_file = os.path.join(os.getenv('APPDATA'), 'dummy.txt')
#      31     post_url = 'http://httpbin.org/post'
#      32     with open(dummy_file, 'wb') as dummy:
#
# /usr/lib/python3.6/posixpath.py in join(a, *p)
#      78     will be discarded.  An empty last part will result in a path that
#      79     ends with a separator."""
# ---> 80     a = os.fspath(a)
#      81     sep = _get_sep(a)
#      82     path = a
#
# TypeError: expected str, bytes or os.PathLike object, not NoneType

# %%
import urllib.request
url='https://fast.com'
page=urllib.request.urlopen(url)
pagetext=page.read() 
pagetext
# Out:
# b'<!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd">\n<!-- htmllint id-class-style="dash" -->\n<!-- htmllint attr-name-style="dash" -->\n<html>\n    <head profile="http://www.w3.org/2005/10/profile">\n        <meta http-equiv="content-type" content="text/html; charset=UTF-8">\n        <meta charset="UTF-8">\n        <meta name="description" content="How fast is your download speed? In seconds, FAST.com&#39;s simple Internet speed test will estimate your ISP speed.">\n        <link href="https://fast.com" rel="canonical">\n\n        <link rel="alternate" hreflang="id" href="https://fast.com/id/" />\n        <link rel="alternate" hreflang="da" href="https://fast.com/da/" />\n        <link rel="alternate" hreflang="de" href="https://fast.com/de/" />\n        <link rel="alternate" hreflang="en-GB" href="https://fast.com/en/gb/" />\n        <link rel="alternate" hreflang="en" href="https://fast.com" />\n        <link rel="alternate" hreflang="es-ES" href="https://fast.com/es/es/" />\n        <link rel="alternate" hreflang="es" href="https://fast.com/es/" />\n        <link rel="alternate" hreflang="fr-CA" href="https://fast.com/fr/ca/" />\n        <link rel="alternate" hreflang="fr" href="https://fast.com/fr/" />\n        <link rel="alternate" hreflang="it" href="https://fast.com/it/" />\n        <link rel="alternate" hreflang="nl" href="https://fast.com/nl/" />\n        <link rel="alternate" hreflang="nb" href="https://fast.com/nb/" />\n        <link rel="alternate" hreflang="pl" href="https://fast.com/pl/" />\n        <link rel="alternate" hreflang="pt" href="https://fast.com/pt/" />\n        <link rel="alternate" hreflang="pt-PT" href="https://fast.com/pt/pt/" />\n        <link rel="alternate" hreflang="ro" href="https://fast.com/ro/" />\n        <link rel="alternate" hreflang="fi" href="https://fast.com/fi/" />\n        <link rel="alternate" hreflang="sv" href="https://fast.com/sv/" />\n        <link rel="alternate" hreflang="tr" href="https://fast.com/tr/" />\n        <link rel="alternate" hreflang="el" href="https://fast.com/el/" />\n        <link rel="alternate" hreflang="he" href="https://fast.com/he/" />\n        <link rel="alternate" hreflang="ar" href="https://fast.com/ar/" />\n        <link rel="alternate" hreflang="th" href="https://fast.com/th/" />\n        <link rel="alternate" hreflang="zh-CN" href="https://fast.com/zh/cn/" />\n        <link rel="alternate" hreflang="zh-TW" href="https://fast.com/zh/tw/" />\n        <link rel="alternate" hreflang="ja" href="https://fast.com/ja/" />\n        <link rel="alternate" hreflang="ko" href="https://fast.com/ko/" />\n        <link type="text/css" rel="stylesheet" href="/app-809f4b.css" media="all">\n        <link type="text/css" rel="stylesheet" href="/assets/fonts/oc-webfont.min.css" media="all">\n        <link rel="icon" type="image/png" href="/assets/favicons/favicon-96x96.png" />\n        <link rel="apple-touch-icon" sizes="57x57" href="/assets/favicons/apple-icon-57x57.png">\n        <link rel="apple-touch-icon" sizes="60x60" href="/assets/favicons/apple-icon-60x60.png">\n        <link rel="apple-touch-icon" sizes="72x72" href="/assets/favicons/apple-icon-72x72.png">\n        <link rel="apple-touch-icon" sizes="76x76" href="/assets/favicons/apple-icon-76x76.png">\n        <link rel="apple-touch-icon" sizes="114x114" href="/assets/favicons/apple-icon-114x114.png">\n        <link rel="apple-touch-icon" sizes="120x120" href="/assets/favicons/apple-icon-120x120.png">\n        <link rel="apple-touch-icon" sizes="144x144" href="/assets/favicons/apple-icon-144x144.png">\n        <link rel="apple-touch-icon" sizes="152x152" href="/assets/favicons/apple-icon-152x152.png">\n        <link rel="apple-touch-icon" sizes="180x180" href="/assets/favicons/apple-icon-180x180.png">\n        <link rel="icon" type="image/png" sizes="192x192"  href="/assets/favicons/android-icon-192x192.png">\n        <link rel="icon" type="image/png" sizes="32x32" href= ...
